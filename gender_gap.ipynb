# %% [markdown]
# ### Introduction to the data set

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(21, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# ### Comparing all categories
#
# In this step, the lists **stem_cats**, **lib_arts_cats**, and **other_cats** are ordered in descending order by the percentage of degrees awarded to women.

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
fig = plt.figure(figsize=(11, 21))

y= 1
for i in range(0,len(stem_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[stem_cats[i]], c=cb_orange, linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,85,'Women')
        ax.text(2005,10,'Men')
    elif i == 5:
        ax.text(2005,72,"Men")
        ax.text(2001,28,"Women")

y = 2
for i in range(0,len(lib_arts_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[lib_arts_cats[i]], c=cb_orange,linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,78,'Women')
        ax.text(2002,18,'Men')
    elif i == 4:
        ax.text(1970,70,"Men")
        ax.text(1970,25,"Women")
      
y = 3
for i in range(0,len(other_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[other_cats[i]], c=cb_orange,linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,90,'Women')
        ax.text(2005,6,'Men')
    elif i == 5:
        ax.text(2005,62,"Men")
        ax.text(2001,33,"Women")

plt.show()

# %% [markdown]
# ### Some improvements on Visualization
#
# Removing the X-axis labels for all line charts except the bottommost line charts in each column

# %%
fig = plt.figure(figsize=(11, 21))

y= 1
for i in range(0,len(stem_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[stem_cats[i]], c=cb_orange, linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,85,'Women')
        ax.text(2005,10,'Men')
    elif i == 5:
        ax.text(2005,72,"Men")
        ax.text(2001,28,"Women")

ax.tick_params(labelbottom="on")

y = 2
for i in range(0,len(lib_arts_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[lib_arts_cats[i]], c=cb_orange,linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,78,'Women')
        ax.text(2002,18,'Men')
    elif i == 4:
        ax.text(1970,70,"Men")
        ax.text(1970,25,"Women")

ax.tick_params(labelbottom="on")

y = 3
for i in range(0,len(other_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[other_cats[i]], c=cb_orange,linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    
    if i == 0:
        ax.text(2000,90,'Women')
        ax.text(2005,6,'Men')
    elif i == 5:
        ax.text(2005,62,"Men")
        ax.text(2001,33,"Women")

ax.tick_params(labelbottom="on")
plt.show()

# %% [markdown]
# ### Additional Improvements on Visualization
#
# Keeping just the starting and ending labels (0 and 100) for all the Y-axis charts

# %%
fig = plt.figure(figsize=(11, 21))

y= 1
for i in range(0,len(stem_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[stem_cats[i]], c=cb_orange, linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(stem_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,85,'Women')
        ax.text(2005,10,'Men')
    elif i == 5:
        ax.text(2005,72,"Men")
        ax.text(2001,28,"Women")

ax.tick_params(labelbottom="on")

y = 2
for i in range(0,len(lib_arts_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[lib_arts_cats[i]], c=cb_orange,linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(lib_arts_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,78,'Women')
        ax.text(2002,18,'Men')
    elif i == 4:
        ax.text(1970,70,"Men")
        ax.text(1970,25,"Women")

ax.tick_params(labelbottom="on")

y = 3
for i in range(0,len(other_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[other_cats[i]], c=cb_orange,linewidth=3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(other_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    
    if i == 0:
        ax.text(2000,90,'Women')
        ax.text(2005,6,'Men')
    elif i == 5:
        ax.text(2005,62,"Men")
        ax.text(2001,33,"Women")

ax.tick_params(labelbottom="on")
plt.show()

# %% [markdown]
# ### Emphisize Gener Breakdown Visualization
#
# By adding a horizontal 'light gray' line

# %%
fig = plt.figure(figsize=(11, 21))
cb_light_gray = [171/255,171/255,171/255]

y= 1
for i in range(0,len(stem_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[stem_cats[i]], c=cb_orange, linewidth=3)
    
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(stem_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,85,'Women')
        ax.text(2005,10,'Men')
    elif i == 5:
        ax.text(2005,72,"Men")
        ax.text(2001,28,"Women")

ax.tick_params(labelbottom="on")

y = 2
for i in range(0,len(lib_arts_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[lib_arts_cats[i]], c=cb_orange,linewidth=3)
    
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(lib_arts_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,78,'Women')
        ax.text(2002,18,'Men')
    elif i == 4:
        ax.text(1970,70,"Men")
        ax.text(1970,25,"Women")

ax.tick_params(labelbottom="on")

y = 3
for i in range(0,len(other_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[other_cats[i]], c=cb_orange,linewidth=3)
    
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(other_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    
    if i == 0:
        ax.text(2000,90,'Women')
        ax.text(2005,6,'Men')
    elif i == 5:
        ax.text(2005,62,"Men")
        ax.text(2001,33,"Women")

ax.tick_params(labelbottom="on")
plt.show()

# %% [markdown]
# ### Exporting to a file
#
# It is possible to export all of the plots contained in the figure as a single image file, but it has to be done before displaying the figure itself (`pyplot.show()`)

# %%
fig = plt.figure(figsize=(11, 21))
cb_light_gray = [171/255,171/255,171/255]

y= 1
for i in range(0,len(stem_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[stem_cats[i]], c=cb_orange, linewidth=3)
    
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(stem_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,85,'Women')
        ax.text(2005,10,'Men')
    elif i == 5:
        ax.text(2005,72,"Men")
        ax.text(2001,28,"Women")

ax.tick_params(labelbottom="on")

y = 2
for i in range(0,len(lib_arts_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[lib_arts_cats[i]], c=cb_orange,linewidth=3)
    
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(lib_arts_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if i == 0:
        ax.text(2000,78,'Women')
        ax.text(2002,18,'Men')
    elif i == 4:
        ax.text(1970,70,"Men")
        ax.text(1970,25,"Women")

ax.tick_params(labelbottom="on")

y = 3
for i in range(0,len(other_cats)):
    ax = fig.add_subplot(6,3,y)
    y = y+3
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[other_cats[i]], c=cb_orange,linewidth=3)
    
    ax.axhline(50, c = cb_light_gray, alpha = 0.3)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(other_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    
    if i == 0:
        ax.text(2000,90,'Women')
        ax.text(2005,6,'Men')
    elif i == 5:
        ax.text(2005,62,"Men")
        ax.text(2001,33,"Women")

ax.tick_params(labelbottom="on")

plt.savefig("gender_degrees.png")

plt.show()
